# %%
import pandas as pd
df = pd.read_csv('House Price India.csv')

# %%
print(df.head())
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      4000               1.5                   0                0
# 1      9480               1.5                   0                0
# 2     42998               2.0                   0                0
# 3      4500               1.5                   0                0
# 4      4750               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1909                0       122004
# 1                       3  ...        1939                0       122004
# 2                       3  ...        2001                0       122005
# 3                       4  ...        1929                0       122006
# 4                       4  ...        1951                0       122007
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8878   -114.470               2470            4000
# 1    52.8852   -114.468               2940            6600
# 2    52.9532   -114.321               3350           42847
# 3    52.9047   -114.485               2060            4500
# 4    52.9133   -114.590               2380            4750
#
#    Number of schools nearby  Distance from the airport      Price
# 0                         2                       51.0  1400000.0
# 1                         1                       53.0  1200000.0
# 2                         3                       76.0   838000.0
# 3                         1                       51.0   805000.0
# 4                         1                       67.0   790000.0
#
# [5 rows x 23 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10052 entries, 0 to 10051
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     10052 non-null  int64
#  1   Date                                   10052 non-null  int64
#  2   number of bedrooms                     10052 non-null  int64
#  3   number of bathrooms                    10052 non-null  float64
#  4   living area                            10052 non-null  int64
#  5   lot area                               10052 non-null  int64
#  6   number of floors                       10052 non-null  float64
#  7   waterfront present                     10052 non-null  int64
#  8   number of views                        10052 non-null  int64
#  9   condition of the house                 10052 non-null  int64
#  10  grade of the house                     10052 non-null  int64
#  11  Area of the house(excluding basement)  10052 non-null  int64
#  12  Area of the basement                   10052 non-null  int64
#  13  Built Year                             10052 non-null  int64
#  14  Renovation Year                        10052 non-null  int64
#  15  Postal Code                            10052 non-null  int64
#  16  Lattitude                              10052 non-null  float64
#  17  Longitude                              10052 non-null  float64
#  18  living_area_renov                      10052 non-null  int64
#  19  lot_area_renov                         10052 non-null  int64
#  20  Number of schools nearby               10052 non-null  int64
#  21  Distance from the airport              10051 non-null  float64
#  22  Price                                  10051 non-null  float64
# dtypes: float64(6), int64(17)
# memory usage: 1.8 MB
# None

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10051 entries, 0 to 10050
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     10051 non-null  int64
#  1   Date                                   10051 non-null  int64
#  2   number of bedrooms                     10051 non-null  int64
#  3   number of bathrooms                    10051 non-null  float64
#  4   living area                            10051 non-null  int64
#  5   lot area                               10051 non-null  int64
#  6   number of floors                       10051 non-null  float64
#  7   waterfront present                     10051 non-null  int64
#  8   number of views                        10051 non-null  int64
#  9   condition of the house                 10051 non-null  int64
#  10  grade of the house                     10051 non-null  int64
#  11  Area of the house(excluding basement)  10051 non-null  int64
#  12  Area of the basement                   10051 non-null  int64
#  13  Built Year                             10051 non-null  int64
#  14  Renovation Year                        10051 non-null  int64
#  15  Postal Code                            10051 non-null  int64
#  16  Lattitude                              10051 non-null  float64
#  17  Longitude                              10051 non-null  float64
#  18  living_area_renov                      10051 non-null  int64
#  19  lot_area_renov                         10051 non-null  int64
#  20  Number of schools nearby               10051 non-null  int64
#  21  Distance from the airport              10051 non-null  float64
#  22  Price                                  10051 non-null  float64
# dtypes: float64(6), int64(17)
# memory usage: 1.8 MB

# %%
from sklearn.ensemble import  RandomForestRegressor 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error

# %%
x=df.drop('Price',axis=1)
y=df['Price']

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

model = RandomForestRegressor()
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([320523.  , 345205.3 , 802695.82, ..., 503930.02, 864912.11,
#        200435.09])

# %%
r2=r2_score(y_test,y_pred) 
ae=mean_absolute_error(y_test,y_pred)
sr=root_mean_squared_error(y_test,y_pred)

# %%
print('r2_score:',r2)
print('mean_absolute_error:',ae)
print('root_mean_squared:',sr)
# Out:
# r2_score: 0.9773427182129178
# mean_absolute_error: 13896.660661362504
# root_mean_squared: 51899.85813424955

# %%
import numpy as np 

np.mean(y)
# Out:
# 543817.7639040891

# %%
df.hist(figsize=(18,20))
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'Date'}>,
#         <Axes: title={'center': 'number of bedrooms'}>,
#         <Axes: title={'center': 'number of bathrooms'}>,
#         <Axes: title={'center': 'living area'}>],
#        [<Axes: title={'center': 'lot area'}>,
#         <Axes: title={'center': 'number of floors'}>,
#         <Axes: title={'center': 'waterfront present'}>,
#         <Axes: title={'center': 'number of views'}>,
#         <Axes: title={'center': 'condition of the house'}>],
#        [<Axes: title={'center': 'grade of the house'}>,
#         <Axes: title={'center': 'Area of the house(excluding basement)'}>,
#         <Axes: title={'center': 'Area of the basement'}>,
#         <Axes: title={'center': 'Built Year'}>,
#         <Axes: title={'center': 'Renovation Year'}>],
#        [<Axes: title={'center': 'Postal Code'}>,
#         <Axes: title={'center': 'Lattitude'}>,
#         <Axes: title={'center': 'Longitude'}>,
#         <Axes: title={'center': 'living_area_renov'}>,
#         <Axes: title={'center': 'lot_area_renov'}>],
#        [<Axes: title={'center': 'Number of schools nearby'}>,
#         <Axes: title={'center': 'Distance from the airport'}>,
#         <Axes: title={'center': 'Price'}>, <Axes: >, <Axes: >]],
#       dtype=object)
